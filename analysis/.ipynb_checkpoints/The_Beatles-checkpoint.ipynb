# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df_main = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data.csv')
df_by_artist = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_artist.csv', index_col = 0)

# %%
df_beatles = df_main[df_main['artists'] == "['The Beatles']"]
df_beatles.head(10)
# Out:
#       acousticness          artists  danceability  duration_ms  energy  \
# 2755        0.6670  ['The Beatles']         0.901       175547   0.548
# 2756        0.9220  ['The Beatles']         0.508       281493   0.311
# 2798        0.0362  ['The Beatles']         0.590       165613   0.448
# 2841        0.3520  ['The Beatles']         0.597       156720   0.660
# 2844        0.2940  ['The Beatles']         0.705       165160   0.427
# 3050        0.9550  ['The Beatles']         0.408       217227   0.187
# 4856        0.6470  ['The Beatles']         0.672       259907   0.529
# 4878        0.3850  ['The Beatles']         0.631       137587   0.748
# 4949        0.1990  ['The Beatles']         0.549       140600   0.725
# 7527        0.8360  ['The Beatles']         0.521       125227   0.301
#
#       explicit                      id  instrumentalness  key  liveness  \
# 2755         0  2ac3duEVpfrlgx4FGoPvxA          0.837000    0    0.1610
# 2756         0  3FplMj2gYs4cymgvLvl8sO          0.000087    4    0.1250
# 2798         0  1gJy93yw33uBxRHZn8KFEz          0.000000    3    0.1040
# 2841         0  33M8Tg2vvZYsmJIuGa3zZd          0.009130    0    0.6930
# 2844         0  4CEoeG1rCKomLu9DtRvX5l          0.000000    4    0.3550
# 3050         0  2Z6L3d10hFhySPcs6lgByo          0.000575    9    0.0766
# 4856         0  2k7gS1tS9OHeS3e8MatzgJ          0.000000    2    0.1470
# 4878         0  1tM9TBNPjieSOZ2d5VAQ1y          0.308000    2    0.2050
# 4949         0  7iTjGs5z7opNGCXyurs0Q7          0.000000    0    0.1780
# 7527         0  6EOKwO6WaLal58MSsi6U4W          0.000000    4    0.3980
#
#       loudness  mode                                               name  \
# 2755    -6.808     1                 Penny Lane - Take 6 / Instrumental
# 2756   -12.204     0                         A Day In The Life - Take 1
# 2798   -11.901     1                                        Lovely Rita
# 2841    -9.499     1  Sgt. Pepper's Lonely Hearts Club Band - Take 9...
# 2844   -11.971     1                 With A Little Help From My Friends
# 3050   -15.354     1                            Something - Studio Demo
# 4856   -11.566     1  You Know My Name (Look Up The Number) - Remast...
# 4878    -7.604     1                     Lady Madonna - Remastered 2009
# 4949    -8.512     1                          Bad Boy - Remastered 2009
# 7527    -7.118     0                                      Eleanor Rigby
#
#       popularity release_date  speechiness    tempo  valence  year
# 2755          29   1967-05-26       0.0996  120.775    0.135  1967
# 2756          29   1967-05-26       0.0403   84.655    0.200  1967
# 2798          27   1967-05-26       0.0256   86.656    0.680  1967
# 2841          29   1967-05-26       0.0771   95.664    0.556  1967
# 2844          27   1967-05-26       0.0353  112.294    0.827  1967
# 3050          30   1969-09-26       0.0350  139.822    0.243  1969
# 4856          38   1988-03-07       0.2000  118.822    0.696  1988
# 4878          36   1988-03-07       0.0300  109.110    0.780  1988
# 4949          37   1988-03-07       0.0431  134.640    0.878  1988
# 7527          57   2014-01-01       0.0356  137.382    0.621  2014

# %%
df2 = df_beatles.loc[:, ['acousticness', 'danceability', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'year']]
df2.reset_index(drop = True)
# Out:
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0         0.66700         0.901  0.5480          0.837000    0    0.1610
# 1         0.92200         0.508  0.3110          0.000087    4    0.1250
# 2         0.03620         0.590  0.4480          0.000000    3    0.1040
# 3         0.35200         0.597  0.6600          0.009130    0    0.6930
# 4         0.29400         0.705  0.4270          0.000000    4    0.3550
# ..            ...           ...     ...               ...  ...       ...
# 405       0.93100         0.442  0.0782          0.895000    4    0.1080
# 406       0.00561         0.656  0.8650          0.000104    4    0.0853
# 407       0.31100         0.571  0.7880          0.000004    7    0.2870
# 408       0.44900         0.553  0.7100          0.000001    2    0.0989
# 409       0.57000         0.492  0.7300          0.000008    7    0.2460
#
#      loudness  speechiness    tempo  valence  year
# 0      -6.808       0.0996  120.775    0.135  1967
# 1     -12.204       0.0403   84.655    0.200  1967
# 2     -11.901       0.0256   86.656    0.680  1967
# 3      -9.499       0.0771   95.664    0.556  1967
# 4     -11.971       0.0353  112.294    0.827  1967
# ..        ...          ...      ...      ...   ...
# 405   -16.256       0.0374  128.584    0.198  1967
# 406    -8.241       0.0311  135.183    0.938  1988
# 407    -8.159       0.0447   90.138    0.769  1988
# 408   -10.492       0.0314  137.717    0.972  1988
# 409    -6.434       0.0416  131.011    0.916  1988
#
# [410 rows x 11 columns]

# %%
fig1 = sns.lineplot(x = 'year', y = 'acousticness', data = df_beatles)
fig1.set_title("How has acousticnessc hanged over time?")
# Out:
# Text(0.5, 1.0, 'How has acousticnessc hanged over time?')

# %%
fig2 = sns.lineplot(x = 'year', y = 'speechiness', data = df_beatles).set_title("How has speechiness changed over time?")

# %%
fig3 = sns.lineplot(x = 'year', y = 'instrumentalness', data = df_beatles).set_title("How has instrumentalness changed over time?")

# %%
features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
x = df2.loc[:, features].values

# %%
y = df2.loc[:,['year']].values

# %%
x = StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data = x, columns = features).head()
# Out:
#    acousticness  danceability    energy  instrumentalness       key  liveness  \
# 0      1.081909      2.691908  0.007336          4.657572 -1.302030 -0.326638
# 1      1.981550     -0.094307 -1.167543         -0.307555 -0.130703 -0.515031
# 2     -1.143554      0.487040 -0.488394         -0.308074 -0.423535 -0.624926
# 3     -0.029411      0.536668  0.562552         -0.253909 -1.302030  2.457387
# 4     -0.234035      1.302345 -0.592497         -0.308074 -0.130703  0.688589
#
#    loudness  speechiness     tempo   valence
# 0  1.021806     0.949109 -0.010728 -1.985485
# 1 -0.895015    -0.270459 -1.333352 -1.719876
# 2 -0.787380    -0.572780 -1.260080  0.241546
# 3  0.065882     0.486372 -0.930230 -0.265155
# 4 -0.812246    -0.373289 -0.321281  0.842231

# %%
pca = PCA(n_components = 2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

# %%
df_beatles_year = df2[['year']]
df_beatles_year.reset_index(drop = True)
df_beatles_year
# Out:
#         year
# 2755    1967
# 2756    1967
# 2798    1967
# 2841    1967
# 2844    1967
# ...      ...
# 164588  1967
# 166656  1988
# 166665  1988
# 166683  1988
# 166696  1988
#
# [410 rows x 1 columns]

# %%
df_beatles_popularity = df_beatles[['popularity']]
df_beatles_popularity.reset_index(drop = True)
df_beatles_popularity
# Out:
#         popularity
# 2755            29
# 2756            29
# 2798            27
# 2841            29
# 2844            27
# ...            ...
# 164588          29
# 166656          37
# 166665          37
# 166683          38
# 166696          38
#
# [410 rows x 1 columns]

# %%
# df_beatles_year.to_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/beatles_year.csv')
# principalDf.to_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/principalDf_beatles.csv')
# df_beatles_popularity.to_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/PCA_data_Zoeb/beatles_popularity.csv')

# %%
finalDf = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/PCA_data_Zoeb/principalDf_beatles.csv')
finalDf
# Out:
#      principal component 1  principal component 2  year  popularity
# 0                 1.490345               0.518493  1967          29
# 1                 2.800503              -0.662215  1967          29
# 2                 0.183568              -1.111396  1967          27
# 3                -0.532409               0.585315  1967          29
# 4                 0.011818              -1.030656  1967          27
# ..                     ...                    ...   ...         ...
# 405               4.918218               1.029595  1967          29
# 406              -2.287576              -0.865138  1988          37
# 407              -1.360985              -0.076337  1988          37
# 408              -0.818416              -1.154475  1988          38
# 409              -1.466697              -0.159975  1988          38
#
# [410 rows x 4 columns]

# %%
sns.set_theme(style = "darkgrid")
sns.set_context("notebook")
ax = sns.relplot(x = 'principal component 1', y = 'principal component 2', hue = 'year', size = 'popularity', sizes=(10, 200), palette = "mako", data = finalDf)
