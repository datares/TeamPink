# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df_main = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data.csv')
df_by_artist = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_artist.csv', index_col = 0)
df_by_genres = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_genres.csv', index_col = 0)
df_by_year = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_year.csv', index_col = 0)
df_w_genres = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_w_genres.csv', index_col = 0)

# %%
df_main
# Out:
#                                                artists  danceability  \
# acousticness
# 0.9950                             ['Carl Woitschach']         0.708
# 0.9940        ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 0.6040                         ['Seweryn Goszczyński']         0.749
# 0.9950                            ['Francisco Canaro']         0.781
# 0.9900        ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...                                                ...           ...
# 0.1730                          ['DripReport', 'Tyga']         0.875
# 0.0167              ['Leon Bridges', 'Terrace Martin']         0.719
# 0.5380                           ['Kygo', 'Oh Wonder']         0.514
# 0.0714                   ['Cash Cash', 'Andy Grammer']         0.646
# 0.1090                              ['Ingrid Andress']         0.512
#
#               duration_ms  energy  explicit                      id  \
# acousticness
# ...

# %%
# cleaning up df_main
df_main['artists'] = df_main['artists'].apply(lambda x: x[1:-1].split(', ')) # makes the string lists in artists column into actual lists
df_main = df_main.explode('artists') # opens the lists so that each artist is on a song has his own row with the song
df_main['artists'] = df_main['artists'].apply(lambda x: x.strip("'")) #  we want to take off the quotes on the artists
df_main_important_info =  df_main.loc[:,['artists','name','popularity','year']] # we will just focus on these columns for now, and rename our data to raw_data
df_main_important_info
# Out:
#                     artists                                           name  \
# 0           Carl Woitschach                    Singende Bataillone 1. Teil
# 1           Robert Schumann       Fantasiestücke, Op. 111: Più tosto lento
# 1         Vladimir Horowitz       Fantasiestücke, Op. 111: Più tosto lento
# 2       Seweryn Goszczyński                 Chapter 1.18 - Zamek kaniowski
# 3          Francisco Canaro  Bebamos Juntos - Instrumental (Remasterizado)
# ...                     ...                                            ...
# 169906                 Kygo                               How Would I Know
# 169906            Oh Wonder                               How Would I Know
# 169907            Cash Cash                                    I Found You
# 169907         Andy Grammer                                    I Found You
# 169908       Ingrid Andress                          More Hearts Than Mine
#
#         popularity  year
# 0                0  1928
# ...

# %%
# this cell will show us how many songs each artist has
most_tracks_by_artist = df_main_important_info['artists'].value_counts()
most_tracks_by_artist
# Out:
# Francisco Canaro           2234
# Эрнест Хемингуэй           1215
# Frédéric Chopin            1035
# Ludwig van Beethoven        976
# Wolfgang Amadeus Mozart     938
#                            ...
# Moriah Hazeltine              1
# Allen Stone                   1
# Male Pétro drummers           1
# Cult Jam                      1
# Ondi Vil                      1
# Name: artists, Length: 27752, dtype: int64

# %%
# this cell gives us the top 200 songs in the dataset
df_main.sort_values(by = ['popularity'], inplace = True, ascending = False)
df_main_top200 = df_main.head(200)
df_main_top200
# Out:
#                                                  artists  danceability  \
# acousticness
# 0.00146                                   ['The Weeknd']         0.514
# 0.24700                        ['DaBaby', 'Roddy Ricch']         0.746
# 0.73100                         ['Powfu', 'beabadoobee']         0.726
# 0.23300       ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']         0.716
# 0.32100                                        ['Drake']         0.834
# ...                                                  ...           ...
# 0.11500                                   ['IU', 'SUGA']         0.676
# 0.29700                                       ['Halsey']         0.752
# 0.89400                      ['Kina', 'Adriana Proenza']         0.522
# 0.16300                       ['Drake', 'Playboi Carti']         0.825
# 0.03320                                        ['Drake']         0.754
#
#               duration_ms  energy  explicit                      id  \
# acousticness
# ...

# %%
sns.lineplot(x = 'year', y = 'instrumentalness', data = df_main_top200) # clearly this doesn't work well

# %%
# this cell gives us the top 200 genres - looked quite different from what I imagined
df_by_genres.sort_values(by = ['popularity'], inplace = True, ascending = False)
top_200_genres = df_by_genres.head(200)

# %%
sns.lineplot(x = 'liveness', y = 'popularity', data = top_200_genres) # hmm this doesn't look too good either

# %%
# this cell gives us the top 200 artists with genres
df_w_genres.sort_values(by = ['popularity'], inplace = True, ascending = False)
top_200_artists_w_genres = df_w_genres.head(200)
top_200_artists_w_genres
# Out:
#                 acousticness  danceability    duration_ms    energy  \
# artists
# Emilee              0.068600      0.674000  176547.000000  0.774000
# StaySolidRocky      0.749000      0.728000  147800.000000  0.431000
# A7S                 0.223000      0.789000  166794.000000  0.720000
# Topic               0.223000      0.789000  166794.000000  0.720000
# Regard              0.177000      0.880000  157606.000000  0.751000
# ...                      ...           ...            ...       ...
# Judy Santos         0.416000      0.804000  254720.000000  0.560000
# NiiHWA              0.089700      0.679000  133673.000000  0.645000
# Absofacto           0.230000      0.688000  224661.000000  0.582000
# Jaira Burns         0.018300      0.566000  191100.000000  0.769000
# Krono               0.063133      0.740667  236684.333333  0.731667
#
#                 instrumentalness  liveness   loudness  speechiness    tempo  \
# artists
# ...

# %%
# this cell gives us the top 200 artists
df_by_artist.sort_values(by = ['popularity'], inplace = True, ascending = False)
top_200_artists = df_by_artist.head(200)
top_200_artists
# Out:
#                   acousticness  danceability  duration_ms  energy  \
# artists
# Emilee                 0.06860         0.674     176547.0   0.774
# StaySolidRocky         0.74900         0.728     147800.0   0.431
# A7S                    0.22300         0.789     166794.0   0.720
# Topic                  0.22300         0.789     166794.0   0.720
# Regard                 0.17700         0.880     157606.0   0.751
# ...                        ...           ...          ...     ...
# Cast of Frozen 2       0.61300         0.566     209965.0   0.543
# Joseph Black           0.11800         0.734     159171.0   0.596
# Molchat Doma           0.69900         0.484     141395.0   0.749
# Mr Eazi                0.07925         0.778     202760.0   0.797
# Tiko                   0.65100         0.908     132885.0   0.342
#
#                   instrumentalness  liveness  loudness  speechiness    tempo  \
# artists
# ...
