# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
#import scanpy as sc

# %%
df_main = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data.csv')
df_by_artist = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_artist.csv', index_col = 0)
df_by_genres = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_genres.csv', index_col = 0)
df_by_year = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_by_year.csv', index_col = 0)
df_w_genres = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/rawdata/data_w_genres.csv', index_col = 0)

# %%
df_main['artists'] = df_main['artists'].apply(lambda x: x[1:-1].split(', ')) # makes the string lists in artists column into actual lists
df_main = df_main.explode('artists') # opens the lists so that each artist is on a song has his own row with the song
df_main['artists'] = df_main['artists'].apply(lambda x: x.strip("'")) #  we want to take off the quotes on the artists
df_main_important_info =  df_main.loc[:,['artists','name','popularity','year']] # we will just focus on these columns for now, and rename our data to raw_data
df_main
# Out:
#         acousticness              artists  danceability  duration_ms  energy  \
# 0             0.9950      Carl Woitschach         0.708       158648  0.1950
# 1             0.9940      Robert Schumann         0.379       282133  0.0135
# 1             0.9940    Vladimir Horowitz         0.379       282133  0.0135
# 2             0.6040  Seweryn Goszczyński         0.749       104300  0.2200
# 3             0.9950     Francisco Canaro         0.781       180760  0.1300
# ...              ...                  ...           ...          ...     ...
# 169906        0.5380                 Kygo         0.514       180700  0.5390
# 169906        0.5380            Oh Wonder         0.514       180700  0.5390
# 169907        0.0714            Cash Cash         0.646       167308  0.7610
# 169907        0.0714         Andy Grammer         0.646       167308  0.7610
# 169908        0.1090       Ingrid Andress         0.512       214787  0.4280
#
# ...

# %%
df_main_for_PCA = df_main.loc[:, ['danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence', 'tempo', 'key']]
song_name = df_main.loc[:, ['name']]

# %%
df_main_for_PCA
# Out:
#         danceability  energy  instrumentalness  liveness  speechiness  \
# 0              0.708  0.1950           0.56300    0.1510       0.0506
# 1              0.379  0.0135           0.90100    0.0763       0.0462
# 1              0.379  0.0135           0.90100    0.0763       0.0462
# 2              0.749  0.2200           0.00000    0.1190       0.9290
# 3              0.781  0.1300           0.88700    0.1110       0.0926
# ...              ...     ...               ...       ...          ...
# 169906         0.514  0.5390           0.00233    0.1080       0.1050
# 169906         0.514  0.5390           0.00233    0.1080       0.1050
# 169907         0.646  0.7610           0.00000    0.2220       0.0385
# 169907         0.646  0.7610           0.00000    0.2220       0.0385
# 169908         0.512  0.4280           0.00000    0.1050       0.0271
#
#         valence    tempo  key
# 0        0.7790  118.469   10
# 1        0.0767   83.972    8
# 1        0.0767   83.972    8
# ...

# %%
song_name
# Out:
#                                                  name
# 0                         Singende Bataillone 1. Teil
# 1            Fantasiestücke, Op. 111: Più tosto lento
# 1            Fantasiestücke, Op. 111: Più tosto lento
# 2                      Chapter 1.18 - Zamek kaniowski
# 3       Bebamos Juntos - Instrumental (Remasterizado)
# ...                                               ...
# 169906                               How Would I Know
# 169906                               How Would I Know
# 169907                                    I Found You
# 169907                                    I Found You
# 169908                          More Hearts Than Mine
#
# [226784 rows x 1 columns]

# %%
df_main_for_PCA.to_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/PCA_data.csv')

# %%
song_name.to_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/song_names.csv')

# %%
adata = sc.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/PCA_data.csv')
song_name = pd.read_csv('/Users/zoebjamal/Desktop/DataRes/team_pink/data/cleandata/song_names.csv')
adata.obs("song name") = song_name
